# %%
import requests
import os
import time
import hashlib
import logging
import re
import json
import pandas as pd
import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Headers for SEC API requests
API_HEADERS = {
    'User-Agent': 'Your Name yourname@example.com',  # Replace with your information
    'Accept': 'application/json',
}

HTML_HEADERS = {
    'User-Agent': 'Your Name yourname@example.com',  # Replace with your information
    'Accept-Encoding': 'gzip, deflate',
    'Host': 'www.sec.gov'
}

def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def get_cached_filename(url, directory):
    return os.path.join(directory, hashlib.md5(url.encode()).hexdigest() + '.json')

def download_with_cache(url, cache_dir='sec_cache', headers=None):
    ensure_directory_exists(cache_dir)
    cached_file = get_cached_filename(url, cache_dir)
    
    if os.path.exists(cached_file):
        logging.info(f"Loading cached file for {url}")
        with open(cached_file, 'r', encoding='utf-8') as file:
            return file.read()
    
    logging.info(f"Downloading {url}")
    try:
        if headers is None:
            headers = API_HEADERS
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        content = response.text
        
        with open(cached_file, 'w', encoding='utf-8') as file:
            file.write(content)
        
        time.sleep(0.2)  # Respectful delay after a new download
        return content
    except requests.exceptions.RequestException as e:
        logging.error(f"Error downloading {url}: {e}")
        return None

def get_cik(ticker):
    ticker = ticker.upper()
    url = "https://www.sec.gov/include/ticker.txt"
    content = download_with_cache(url, 'sec_data')
    if content:
        for line in content.splitlines():
            t, c = line.strip().split('\t')
            if t.upper() == ticker:
                return c.zfill(10)
    logging.error(f"CIK not found for ticker {ticker}")
    return None

def get_financial_data(ticker, concepts):
    cik = get_cik(ticker)
    if not cik:
        logging.error(f"Failed to get CIK for {ticker}")
        return None
    
    # Define the date 20 years ago from today
    ten_years_ago = datetime.datetime.now() - datetime.timedelta(days=365 * 20)
    ten_years_ago_str = ten_years_ago.strftime('%Y-%m-%d')
    
    financial_data = {}
    for concept in concepts:
        url = f"https://data.sec.gov/api/xbrl/companyconcept/CIK{cik}/us-gaap/{concept}.json"
        content = download_with_cache(url, cache_dir='sec_data', headers=API_HEADERS)
        if not content:
            logging.error(f"Failed to get data for {ticker} and concept {concept}")
            continue
        data = json.loads(content)
        concept_data = []
        for unit in data.get('units', {}):
            for fact in data['units'][unit]:
                # Filter by date
                fact_end_date = fact.get('end')
                if fact_end_date and fact_end_date >= ten_years_ago_str:
                    concept_data.append({
                        'date': fact_end_date,
                        'value': fact.get('val'),
                        'unit': unit,
                        'concept': concept,
                        'form': fact.get('form'),
                        'filed': fact.get('filed'),
                        'fy': fact.get('fy'),
                        'fp': fact.get('fp'),
                    })
        # Sort the list by date in descending order
        concept_data.sort(key=lambda x: x['date'], reverse=True)
        financial_data[concept] = concept_data
    return financial_data

def save_financial_data_to_csv(ticker, financial_data, concepts):
    cik = get_cik(ticker)
    if not cik:
        logging.error(f"Failed to get CIK for {ticker}")
        return None
    
    # Create 'fundamentals' folder if it doesn't exist
    ensure_directory_exists('fundamentals')
    
    # Collect all dates
    all_dates = set()
    for concept in financial_data:
        for item in financial_data[concept]:
            all_dates.add(item['date'])
    all_dates = sorted(all_dates, reverse=True)
    
    # Build rows
    rows = []
    for date in all_dates:
        row = {'date': date}
        for concept in concepts:
            # Find the value for this date
            value = None
            unit = None
            form = None
            filed = None
            fy = None
            fp = None
            for item in financial_data.get(concept, []):
                if item['date'] == date:
                    value = item['value']
                    unit = item['unit']
                    form = item['form']
                    filed = item['filed']
                    fy = item['fy']
                    fp = item['fp']
                    break
            row[concept] = value
            # Include unit for each concept
            row[f'{concept}_unit'] = unit
        # Include additional metadata (only if available)
        row['form'] = form
        row['filed'] = filed
        row['fy'] = fy
        row['fp'] = fp
        rows.append(row)
    
    # Create DataFrame
    df = pd.DataFrame(rows)
    
    # Save to CSV
    filename = f"fundamentals/{ticker.lower()}-{cik}-EPS.csv"
    df.to_csv(filename, index=False)
    logging.info(f"Saved financial data to {filename}")
    return filename

# Read the Nasdaq-100 companies list
url = 'https://en.wikipedia.org/wiki/Nasdaq-100'
nasdaq100_df = pd.read_html(url, attrs={"class": "wikitable sortable"})[0]

# Clean up column names
nasdaq100_df.columns = nasdaq100_df.columns.str.strip()

# Extract the list of tickers
tickers = nasdaq100_df['Ticker'].tolist()

# Define the financial concepts to fetch
concepts = [
    'EarningsPerShareBasic',
    'EarningsPerShareDiluted',
    'NetIncomeLoss',
    'OperatingIncomeLoss',
    'GrossProfit',
    'Revenues'  # Also known as SalesRevenueNet for some companies
]

# Create 'fundamentals' folder if it doesn't exist
ensure_directory_exists('fundamentals')

# Iterate over tickers
for ticker in tickers:
    logging.info(f"Processing {ticker}")
    try:
        financial_data = get_financial_data(ticker, concepts)
        if financial_data:
            filename = save_financial_data_to_csv(ticker, financial_data, concepts)
            logging.info(f"Financial data for {ticker} saved to {filename}")
        else:
            logging.warning(f"No financial data found for {ticker}")
    except Exception as e:
        logging.error(f"An error occurred while processing {ticker}: {e}")
    # Respectful delay between tickers
    time.sleep(0.5)

# Save the Nasdaq-100 components to a CSV file
nasdaq100_df.to_csv('data/nasdaq100_companies.csv', index=False)
logging.info("Saved Nasdaq-100 components to data/nasdaq100_companies.csv")
# Out:
# 2024-09-21 15:00:06,152 - INFO - Processing ADBE
# 2024-09-21 15:00:06,152 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:06,154 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:06,155 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:06,156 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:06,157 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:06,158 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/GrossProfit.json
# 2024-09-21 15:00:06,158 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/Revenues.json
# 2024-09-21 15:00:06,159 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:06,162 - INFO - Saved financial data to fundamentals/adbe-0000796343-EPS.csv
# 2024-09-21 15:00:06,163 - INFO - Financial data for ADBE saved to fundamentals/adbe-0000796343-EPS.csv
# 2024-09-21 15:00:06,664 - INFO - Processing AMD
# 2024-09-21 15:00:06,665 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:06,665 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:06,666 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:06,667 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:06,668 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:06,669 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/GrossProfit.json
# 2024-09-21 15:00:06,670 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/Revenues.json
# 2024-09-21 15:00:06,670 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:06,673 - INFO - Saved financial data to fundamentals/amd-0000002488-EPS.csv
# 2024-09-21 15:00:06,673 - INFO - Financial data for AMD saved to fundamentals/amd-0000002488-EPS.csv
# 2024-09-21 15:00:07,174 - INFO - Processing ABNB
# 2024-09-21 15:00:07,175 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00
- ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000008670/us-gaap/OperatingIncomeLoss.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000008670/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:34,194 - ERROR - Failed to get data for ADP and concept OperatingIncomeLoss
# 2024-09-21 15:00:34,194 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000008670/us-gaap/GrossProfit.json
# 2024-09-21 15:00:34,195 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000008670/us-gaap/Revenues.json
# 2024-09-21 15:00:34,197 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:34,199 - INFO - Saved financial data to fundamentals/adp-0000008670-EPS.csv
# 2024-09-21 15:00:34,199 - INFO - Financial data for ADP saved to fundamentals/adp-0000008670-EPS.csv
# 2024-09-21 15:00:34,701 - INFO - Processing BKR
# 2024-09-21 15:00:34,701 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:34,702 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:34,704 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:34,704 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:34,705 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:34,706 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/GrossProfit.json
# 2024-09-21 15:00:34,707 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/Revenues.json
# 2024-09-21 15:00:35,321 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001701605/us-gaap/Revenues.json
# 2024-09-21 15:00:35,322 - ERROR - Failed to get data for BKR and concept Revenues
# 2024-09-21 15:00:35,323 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:35,325 - INFO - Saved financial data to fundamentals/bkr-0001701605-EPS.csv
# 2024-09-21 15:00:35,326 - INFO - Financial data for BKR saved to fundamentals/bkr-0001701605-EPS.csv
# 2024-09-21 15:00:35,826 - INFO - Processing BIIB
# 2024-09-21 15:00:35,827 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:35,828 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:35,830 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:35,831 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:35,832 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:35,833 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/GrossProfit.json
# 2024-09-21 15:00:35,834 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000875045/us-gaap/Revenues.json
# 2024-09-21 15:00:35,834 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:35,837 - INFO - Saved financial data to fundamentals/biib-0000875045-EPS.csv
# 2024-09-21 15:00:35,837 - INFO - Financial data for BIIB saved to fundamentals/biib-0000875045-EPS.csv
# 2024-09-21 15:00:36,338 - INFO - Processing BKNG
# 2024-09-21 15:00:36,339 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:36,340 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:36,341 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:36,342 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:36,343 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:36,343 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/GrossProfit.json
# 2024-09-21 15:00:36,344 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001075531/us-gaap/Revenues.json
# 2024-09-21 15:00:36,345 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:36,347 - INFO - Saved financial data to fundamentals/bkng-0001075531-EPS.csv
# 2024-09-21 15:00:36,348 - INFO - Financial data for BKNG saved to fundamentals/bkng-0001075531-EPS.csv
# 2024-09-21 15:00:36,849 - INFO - Processing AVGO
# 2024-09-21 15:00:36,849 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:36,850 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:36,851 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:36,852 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:36,853 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:36,853 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/GrossProfit.json
# 2024-09-21 15:00:36,854 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001730168/us-gaap/Revenues.json
# 2024-09-21 15:00:36,855 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:36,857 - INFO - Saved financial data to fundamentals/avgo-0001730168-EPS.csv
# 2024-09-21 15:00:36,858 - INFO - Financial data for AVGO saved to fundamentals/avgo-0001730168-EPS.csv
# 2024-09-21 15:00:37,359 - INFO - Processing CDNS
# 2024-09-21 15:00:37,359 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:37,360 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:37,361 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:37,362 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:37,363 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:37,364 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/GrossProfit.json
# 2024-09-21 15:00:38,013 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/GrossProfit.json
# 2024-09-21 15:00:38,014 - ERROR - Failed to get data for CDNS and concept GrossProfit
# 2024-09-21 15:00:38,014 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/Revenues.json
# 2024-09-21 15:00:38,579 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000813672/us-gaap/Revenues.json
# 2024-09-21 15:00:38,580 - ERROR - Failed to get data for CDNS and concept Revenues
# 2024-09-21 15:00:38,581 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:38,583 - INFO - Saved financial data to fundamentals/cdns-0000813672-EPS.csv
# 2024-09-21 15:00:38,583 - INFO - Financial data for CDNS saved to fundamentals/cdns-0000813672-EPS.csv
# 2024-09-21 15:00:39,084 - INFO - Processing CDW
# 2024-09-21 15:00:39,085 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:39,086 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:39,087 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:39,088 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:39,089 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:39,090 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/GrossProfit.json
# 2024-09-21 15:00:39,091 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001402057/us-gaap/Revenues.json
# 2024-09-21 15:00:39,092 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:39,094 - INFO - Saved financial data to fundamentals/cdw-0001402057-EPS.csv
# 2024-09-21 15:00:39,094 - INFO - Financial data for CDW saved to fundamentals/cdw-0001402057-EPS.csv
# 2024-09-21 15:00:39,595 - INFO - Processing CHTR
# 2024-09-21 15:00:39,596 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:39,597 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:39,598 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:39,599 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:39,600 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:39,600 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/GrossProfit.json
# 2024-09-21 15:00:40,272 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/GrossProfit.json
# 2024-09-21 15:00:40,273 - ERROR - Failed to get data for CHTR and concept GrossProfit
# 2024-09-21 15:00:40,273 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001091667/us-gaap/Revenues.json
# 2024-09-21 15:00:40,275 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:40,277 - INFO - Saved financial data to fundamentals/chtr-0001091667-EPS.csv
# 2024-09-21 15:00:40,277 - INFO - Financial data for CHTR saved to fundamentals/chtr-0001091667-EPS.csv
# 2024-09-21 15:00:40,778 - INFO - Processing CTAS
# 2024-09-21 15:00:40,779 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:40,780 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:40,782 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:40,782 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:40,783 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:40,784 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/GrossProfit.json
# 2024-09-21 15:00:40,785 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000723254/us-gaap/Revenues.json
# 2024-09-21 15:00:40,786 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:40,788 - INFO - Saved financial data to fundamentals/ctas-0000723254-EPS.csv
# 2024-09-21 15:00:40,789 - INFO - Financial data for CTAS saved to fundamentals/ctas-0000723254-EPS.csv
# 2024-09-21 15:00:41,290 - INFO - Processing CSCO
# 2024-09-21 15:00:41,290 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:41,291 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:41,293 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:41,294 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:41,295 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:41,296 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/GrossProfit.json
# 2024-09-21 15:00:41,297 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000858877/us-gaap/Revenues.json
# 2024-09-21 15:00:41,298 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:41,300 - INFO - Saved financial data to fundamentals/csco-0000858877-EPS.csv
# 2024-09-21 15:00:41,301 - INFO - Financial data for CSCO saved to fundamentals/csco-0000858877-EPS.csv
# 2024-09-21 15:00:41,802 - INFO - Processing CCEP
# 2024-09-21 15:00:41,802 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:41,803 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:42,359 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareBasic.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:42,360 - ERROR - Failed to get data for CCEP and concept EarningsPerShareBasic
# 2024-09-21 15:00:42,360 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:42,916 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareDiluted.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:42,917 - ERROR - Failed to get data for CCEP and concept EarningsPerShareDiluted
# 2024-09-21 15:00:42,917 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:43,525 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/NetIncomeLoss.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:43,526 - ERROR - Failed to get data for CCEP and concept NetIncomeLoss
# 2024-09-21 15:00:43,526 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:44,134 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/OperatingIncomeLoss.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:44,135 - ERROR - Failed to get data for CCEP and concept OperatingIncomeLoss
# 2024-09-21 15:00:44,136 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/GrossProfit.json
# 2024-09-21 15:00:44,987 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/GrossProfit.json
# 2024-09-21 15:00:44,988 - ERROR - Failed to get data for CCEP and concept GrossProfit
# 2024-09-21 15:00:44,989 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/Revenues.json
# 2024-09-21 15:00:45,777 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001650107/us-gaap/Revenues.json
# 2024-09-21 15:00:45,778 - ERROR - Failed to get data for CCEP and concept Revenues
# 2024-09-21 15:00:45,779 - WARNING - No financial data found for CCEP
# 2024-09-21 15:00:46,279 - INFO - Processing CTSH
# 2024-09-21 15:00:46,280 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:46,281 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:46,282 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:46,283 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:46,284 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:46,285 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/GrossProfit.json
# 2024-09-21 15:00:47,145 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/GrossProfit.json
# 2024-09-21 15:00:47,146 - ERROR - Failed to get data for CTSH and concept GrossProfit
# 2024-09-21 15:00:47,147 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001058290/us-gaap/Revenues.json
# 2024-09-21 15:00:47,148 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:47,150 - INFO - Saved financial data to fundamentals/ctsh-0001058290-EPS.csv
# 2024-09-21 15:00:47,151 - INFO - Financial data for CTSH saved to fundamentals/ctsh-0001058290-EPS.csv
# 2024-09-21 15:00:47,652 - INFO - Processing CMCSA
# 2024-09-21 15:00:47,652 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:47,653 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:00:47,655 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:00:47,656 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:00:47,657 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:00:47,658 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/GrossProfit.json
# 2024-09-21 15:00:48,592 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/GrossProfit.json
# 2024-09-21 15:00:48,593 - ERROR - Failed to get data for CMCSA and concept GrossProfit
# 2024-09-21 15:00:48,593 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001166691/us-gaap/Revenues.json
# 2024-09-21 15:00:48,594 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:00:48,597 - INFO - Saved financial data to fundamentals/cmcsa-0001166691-EPS.csv
# 2024-09-21 15:00:48,598 - INFO - Financial data for CMCSA saved to fundamentals/cmcsa-0001166691-EPS.csv
# ...
# 2024-09-21 15:01:45,136 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000896878/us-gaap/GrossProfit.json
# 2024-09-21 15:01:45,664 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000896878/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000896878/us-gaap/GrossProfit.json
# 2024-09-21 15:01:45,665 - ERROR - Failed to get data for INTU and concept GrossProfit
# 2024-09-21 15:01:45,666 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000896878/us-gaap/Revenues.json
# 2024-09-21 15:01:46,494 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:46,497 - INFO - Saved financial data to fundamentals/intu-0000896878-EPS.csv
# 2024-09-21 15:01:46,497 - INFO - Financial data for INTU saved to fundamentals/intu-0000896878-EPS.csv
# 2024-09-21 15:01:46,998 - INFO - Processing ISRG
# 2024-09-21 15:01:46,999 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:47,000 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:01:47,818 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:01:48,657 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:01:49,519 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:01:50,315 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/GrossProfit.json
# 2024-09-21 15:01:51,097 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/Revenues.json
# 2024-09-21 15:01:51,673 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001035267/us-gaap/Revenues.json
# 2024-09-21 15:01:51,674 - ERROR - Failed to get data for ISRG and concept Revenues
# 2024-09-21 15:01:51,674 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:51,677 - INFO - Saved financial data to fundamentals/isrg-0001035267-EPS.csv
# 2024-09-21 15:01:51,677 - INFO - Financial data for ISRG saved to fundamentals/isrg-0001035267-EPS.csv
# 2024-09-21 15:01:52,178 - INFO - Processing KDP
# 2024-09-21 15:01:52,179 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:52,180 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:01:52,946 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:01:53,692 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:01:54,507 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:01:55,360 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/GrossProfit.json
# 2024-09-21 15:01:57,159 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/Revenues.json
# 2024-09-21 15:01:58,839 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001418135/us-gaap/Revenues.json
# 2024-09-21 15:01:58,840 - ERROR - Failed to get data for KDP and concept Revenues
# 2024-09-21 15:01:58,840 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:58,843 - INFO - Saved financial data to fundamentals/kdp-0001418135-EPS.csv
# 2024-09-21 15:01:58,844 - INFO - Financial data for KDP saved to fundamentals/kdp-0001418135-EPS.csv
# 2024-09-21 15:01:59,345 - INFO - Processing KLAC
# 2024-09-21 15:01:59,345 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:01:59,346 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:01,726 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:06,629 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:07,780 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:08,928 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/GrossProfit.json
# 2024-09-21 15:02:10,027 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000319201/us-gaap/Revenues.json
# 2024-09-21 15:02:11,102 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:11,104 - INFO - Saved financial data to fundamentals/klac-0000319201-EPS.csv
# 2024-09-21 15:02:11,105 - INFO - Financial data for KLAC saved to fundamentals/klac-0000319201-EPS.csv
# 2024-09-21 15:02:11,606 - INFO - Processing KHC
# 2024-09-21 15:02:11,606 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:11,607 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:12,672 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:13,726 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:14,796 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:15,808 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/GrossProfit.json
# 2024-09-21 15:02:16,884 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001637459/us-gaap/Revenues.json
# 2024-09-21 15:02:17,933 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:17,936 - INFO - Saved financial data to fundamentals/khc-0001637459-EPS.csv
# 2024-09-21 15:02:17,936 - INFO - Financial data for KHC saved to fundamentals/khc-0001637459-EPS.csv
# 2024-09-21 15:02:18,437 - INFO - Processing LRCX
# 2024-09-21 15:02:18,438 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:18,439 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:19,543 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:20,576 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:21,712 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:22,792 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/GrossProfit.json
# 2024-09-21 15:02:23,928 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000707549/us-gaap/Revenues.json
# 2024-09-21 15:02:25,343 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:25,346 - INFO - Saved financial data to fundamentals/lrcx-0000707549-EPS.csv
# 2024-09-21 15:02:25,346 - INFO - Financial data for LRCX saved to fundamentals/lrcx-0000707549-EPS.csv
# 2024-09-21 15:02:25,847 - INFO - Processing LIN
# 2024-09-21 15:02:25,848 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:25,849 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:26,775 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:27,918 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:29,017 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:30,044 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/GrossProfit.json
# 2024-09-21 15:02:30,932 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/GrossProfit.json
# 2024-09-21 15:02:30,933 - ERROR - Failed to get data for LIN and concept GrossProfit
# 2024-09-21 15:02:30,934 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/Revenues.json
# 2024-09-21 15:02:31,727 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001707925/us-gaap/Revenues.json
# 2024-09-21 15:02:31,728 - ERROR - Failed to get data for LIN and concept Revenues
# 2024-09-21 15:02:31,729 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:31,731 - INFO - Saved financial data to fundamentals/lin-0001707925-EPS.csv
# 2024-09-21 15:02:31,731 - INFO - Financial data for LIN saved to fundamentals/lin-0001707925-EPS.csv
# 2024-09-21 15:02:32,232 - INFO - Processing LULU
# 2024-09-21 15:02:32,233 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:32,233 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:33,321 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:34,419 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:35,458 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:36,489 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/GrossProfit.json
# 2024-09-21 15:02:37,547 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/Revenues.json
# 2024-09-21 15:02:38,364 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001397187/us-gaap/Revenues.json
# 2024-09-21 15:02:38,364 - ERROR - Failed to get data for LULU and concept Revenues
# 2024-09-21 15:02:38,365 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:38,368 - INFO - Saved financial data to fundamentals/lulu-0001397187-EPS.csv
# 2024-09-21 15:02:38,368 - INFO - Financial data for LULU saved to fundamentals/lulu-0001397187-EPS.csv
# 2024-09-21 15:02:38,869 - INFO - Processing MAR
# 2024-09-21 15:02:38,870 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:38,871 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:39,961 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:41,025 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:42,096 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:43,129 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/GrossProfit.json
# 2024-09-21 15:02:43,940 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/GrossProfit.json
# 2024-09-21 15:02:43,941 - ERROR - Failed to get data for MAR and concept GrossProfit
# 2024-09-21 15:02:43,942 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001048286/us-gaap/Revenues.json
# 2024-09-21 15:02:45,025 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:45,028 - INFO - Saved financial data to fundamentals/mar-0001048286-EPS.csv
# 2024-09-21 15:02:45,028 - INFO - Financial data for MAR saved to fundamentals/mar-0001048286-EPS.csv
# 2024-09-21 15:02:45,529 - INFO - Processing MRVL
# 2024-09-21 15:02:45,529 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:45,530 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:46,580 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:02:47,650 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:02:48,712 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:02:49,767 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/GrossProfit.json
# 2024-09-21 15:02:50,809 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/Revenues.json
# 2024-09-21 15:02:51,605 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001835632/us-gaap/Revenues.json
# 2024-09-21 15:02:51,605 - ERROR - Failed to get data for MRVL and concept Revenues
# 2024-09-21 15:02:51,606 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:51,608 - INFO - Saved financial data to fundamentals/mrvl-0001835632-EPS.csv
# 2024-09-21 15:02:51,609 - INFO - Financial data for MRVL saved to fundamentals/mrvl-0001835632-EPS.csv
# 2024-09-21 15:02:52,110 - INFO - Processing MELI
# 2024-09-21 15:02:52,110 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:02:52,111 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001099590/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:02:53,177 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001099590/us-gaap/EarningsPerShareDiluted.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 194
#     192 logging.info(f"Processing {ticker}")
#     193 try:
# --> 194     financial_data = get_financial_data(ticker, concepts)
#     195     if financial_data:
#     196         filename = save_financial_data_to_csv(ticker, financial_data, concepts)
#
# Cell In[1], line 85, in get_financial_data(ticker, concepts)
#      83 for concept in concepts:
#      84     url = f"https://data.sec.gov/api/xbrl/companyconcept/CIK{cik}/us-gaap/{concept}.json"
# ---> 85     content = download_with_cache(url, cache_dir='sec_data', headers=API_HEADERS)
#      86     if not content:
#      87         logging.error(f"Failed to get data for {ticker} and concept {concept}")
#
# Cell In[1], line 54, in download_with_cache(url, cache_dir, headers)
#      51     with open(cached_file, 'w', encoding='utf-8') as file:
#      52         file.write(content)
# ---> 54     time.sleep(0.2)  # Respectful delay after a new download
#      55     return content
#      56 except requests.exceptions.RequestException as e:
#
# KeyboardInterrupt:
