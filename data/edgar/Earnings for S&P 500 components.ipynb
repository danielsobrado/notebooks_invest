# %%
import requests
import os
import time
import hashlib
import logging
import re
import json
import pandas as pd  # For DataFrame and CSV handling
import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Headers for SEC API requests
API_HEADERS = {
    'User-Agent': 'Your Name yourname@example.com',  # Replace with your information
    'Accept': 'application/json',
}

HTML_HEADERS = {
    'User-Agent': 'Your Name yourname@example.com',  # Replace with your information
    'Accept-Encoding': 'gzip, deflate',
    'Host': 'www.sec.gov'
}

def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def get_cached_filename(url, directory):
    return os.path.join(directory, hashlib.md5(url.encode()).hexdigest() + '.json')

def download_with_cache(url, cache_dir='sec_cache', headers=None):
    ensure_directory_exists(cache_dir)
    cached_file = get_cached_filename(url, cache_dir)
    
    if os.path.exists(cached_file):
        logging.info(f"Loading cached file for {url}")
        with open(cached_file, 'r', encoding='utf-8') as file:
            return file.read()
    
    logging.info(f"Downloading {url}")
    try:
        if headers is None:
            headers = API_HEADERS
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        content = response.text
        
        with open(cached_file, 'w', encoding='utf-8') as file:
            file.write(content)
        
        time.sleep(0.2)  # Respectful delay after a new download
        return content
    except requests.exceptions.RequestException as e:
        logging.error(f"Error downloading {url}: {e}")
        return None

def get_cik(ticker):
    ticker = ticker.upper()
    url = "https://www.sec.gov/include/ticker.txt"
    content = download_with_cache(url, 'sec_data')
    if content:
        for line in content.splitlines():
            t, c = line.strip().split('\t')
            if t.upper() == ticker:
                return c.zfill(10)
    logging.error(f"CIK not found for ticker {ticker}")
    return None

def get_financial_data(ticker, concepts):
    cik = get_cik(ticker)
    if not cik:
        logging.error(f"Failed to get CIK for {ticker}")
        return None

    # Define the date 20 years ago from today
    ten_years_ago = datetime.datetime.now() - datetime.timedelta(days=365 * 20)
    ten_years_ago_str = ten_years_ago.strftime('%Y-%m-%d')

    financial_data = {}
    for concept_name, concept_list in concepts.items():
        concept_data = []
        found_data = False
        for concept in concept_list:
            url = f"https://data.sec.gov/api/xbrl/companyconcept/CIK{cik}/us-gaap/{concept}.json"
            content = download_with_cache(url, cache_dir='sec_data', headers=API_HEADERS)
            if not content:
                logging.error(f"Failed to get data for {ticker} and concept {concept}")
                continue
            data = json.loads(content)
            if 'units' in data:
                found_data = True
                for unit in data.get('units', {}):
                    for fact in data['units'][unit]:
                        # Filter by date
                        fact_end_date = fact.get('end')
                        if fact_end_date and fact_end_date >= ten_years_ago_str:
                            concept_data.append({
                                'date': fact_end_date,
                                'value': fact.get('val'),
                                'unit': unit,
                                'concept': concept,
                                'form': fact.get('form'),
                                'filed': fact.get('filed'),
                                'fy': fact.get('fy'),
                                'fp': fact.get('fp'),
                            })
                break  # Exit the loop if data is found for a concept
        if not found_data:
            logging.warning(f"No data found for {ticker} and concepts {concept_list}")
        # Sort the list by date in descending order
        concept_data.sort(key=lambda x: x['date'], reverse=True)
        financial_data[concept_name] = concept_data
    return financial_data

def save_financial_data_to_csv(ticker, financial_data, concepts):
    cik = get_cik(ticker)
    if not cik:
        logging.error(f"Failed to get CIK for {ticker}")
        return None

    # Create 'fundamentals' folder if it doesn't exist
    ensure_directory_exists('fundamentals')

    # Collect all dates
    all_dates = set()
    for concept_data in financial_data.values():
        for item in concept_data:
            all_dates.add(item['date'])
    all_dates = sorted(all_dates, reverse=True)

    # Build rows
    rows = []
    for date in all_dates:
        row = {'date': date}
        for concept_name in concepts.keys():
            # Find the value for this date
            value = None
            unit = None
            form = None
            filed = None
            fy = None
            fp = None
            for item in financial_data.get(concept_name, []):
                if item['date'] == date:
                    value = item['value']
                    unit = item['unit']
                    form = item['form']
                    filed = item['filed']
                    fy = item['fy']
                    fp = item['fp']
                    break
            row[concept_name] = value
            # Include unit for each concept
            row[f'{concept_name}_unit'] = unit
        # Include additional metadata (only if available)
        row['form'] = form
        row['filed'] = filed
        row['fy'] = fy
        row['fp'] = fp
        rows.append(row)

    # Create DataFrame
    df = pd.DataFrame(rows)

    # Save to CSV
    filename = f"fundamentals/{ticker.lower()}-{cik}-financials.csv"
    df.to_csv(filename, index=False)
    logging.info(f"Saved financial data to {filename}")
    return filename

# Read the S&P 500 companies list
sp500_df = pd.read_csv('data/sp500_companies.csv')

# Extract the list of tickers
tickers = sp500_df['Ticker'].tolist()

# Define the financial concepts to fetch with alternatives
concepts = {
    'EarningsPerShareBasic': ['EarningsPerShareBasic'],
    'EarningsPerShareDiluted': ['EarningsPerShareDiluted'],
    'NetIncomeLoss': ['NetIncomeLoss'],
    'OperatingIncomeLoss': ['OperatingIncomeLoss'],
    'GrossProfit': ['GrossProfit'],
    'Revenues': ['Revenues', 'SalesRevenueNet'],  # Alternative tag
    'NetCashProvidedByUsedInOperatingActivities': ['NetCashProvidedByUsedInOperatingActivities'],
    'NetCashProvidedByUsedInInvestingActivities': ['NetCashProvidedByUsedInInvestingActivities'],
    'NetCashProvidedByUsedInFinancingActivities': ['NetCashProvidedByUsedInFinancingActivities'],
    'PaymentsToAcquirePropertyPlantAndEquipment': ['PaymentsToAcquirePropertyPlantAndEquipment'],  # CapEx
    'PaymentsToAcquireBusinessesNetOfCashAcquired': ['PaymentsToAcquireBusinessesNetOfCashAcquired'],
    'ProceedsFromDivestitureOfBusinessesNetOfCashDivested': ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested'],
    'RepaymentsOfLongTermDebt': ['RepaymentsOfLongTermDebt'],
    'ProceedsFromLongTermDebt': ['ProceedsFromLongTermDebt'],
    'PaymentsOfDebtIssuanceCosts': ['PaymentsOfDebtIssuanceCosts'],
    'DividendsPaid': ['PaymentsOfDividendsCommonStock', 'PaymentsOfDividends'],
    'ShareRepurchases': ['PaymentsForRepurchaseOfCommonStock', 'PurchaseOfEquitySecurities']
}

# Create 'fundamentals' folder if it doesn't exist
ensure_directory_exists('fundamentals')

# Iterate over tickers
for ticker in tickers:
    logging.info(f"Processing {ticker}")
    try:
        financial_data = get_financial_data(ticker, concepts)
        if financial_data:
            filename = save_financial_data_to_csv(ticker, financial_data, concepts)
            logging.info(f"Financial data for {ticker} saved to {filename}")
        else:
            logging.warning(f"No financial data found for {ticker}")
    except Exception as e:
        logging.error(f"An error occurred while processing {ticker}: {e}")
    # Respectful delay between tickers
    time.sleep(0.5)
# Out:
# 2024-09-21 15:53:46,190 - INFO - Processing MMM
# 2024-09-21 15:53:46,191 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:46,192 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:53:46,193 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:53:46,194 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:53:46,195 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:53:46,196 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/GrossProfit.json
# 2024-09-21 15:53:47,215 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/GrossProfit.json
# 2024-09-21 15:53:47,216 - ERROR - Failed to get data for MMM and concept GrossProfit
# 2024-09-21 15:53:47,217 - WARNING - No data found for MMM and concepts ['GrossProfit']
# 2024-09-21 15:53:47,217 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/Revenues.json
# 2024-09-21 15:53:47,218 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:53:47,219 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:53:47,219 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:53:47,220 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:53:47,220 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:53:47,221 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:48,053 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:48,054 - ERROR - Failed to get data for MMM and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:53:48,055 - WARNING - No data found for MMM and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:53:48,055 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:53:48,881 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/RepaymentsOfLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:53:48,882 - ERROR - Failed to get data for MMM and concept RepaymentsOfLongTermDebt
# 2024-09-21 15:53:48,883 - WARNING - No data found for MMM and concepts ['RepaymentsOfLongTermDebt']
# 2024-09-21 15:53:48,883 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:49,688 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:49,689 - ERROR - Failed to get data for MMM and concept ProceedsFromLongTermDebt
# 2024-09-21 15:53:49,689 - WARNING - No data found for MMM and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:53:49,690 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:53:50,561 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:53:50,562 - ERROR - Failed to get data for MMM and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:53:50,562 - WARNING - No data found for MMM and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:53:50,563 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:53:50,563 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000066740/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:53:50,564 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:50,569 - INFO - Saved financial data to fundamentals/mmm-0000066740-financials.csv
# 2024-09-21 15:53:50,570 - INFO - Financial data for MMM saved to fundamentals/mmm-0000066740-financials.csv
# 2024-09-21 15:53:51,071 - INFO - Processing AOS
# 2024-09-21 15:53:51,072 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:51,073 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:53:51,073 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:53:51,074 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:53:51,075 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:53:51,076 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/GrossProfit.json
# 2024-09-21 15:53:51,076 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/Revenues.json
# 2024-09-21 15:53:51,862 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/Revenues.json
# 2024-09-21 15:53:51,863 - ERROR - Failed to get data for AOS and concept Revenues
# 2024-09-21 15:53:51,863 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/SalesRevenueNet.json
# 2024-09-21 15:53:52,768 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/SalesRevenueNet.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/SalesRevenueNet.json
# 2024-09-21 15:53:52,769 - ERROR - Failed to get data for AOS and concept SalesRevenueNet
# 2024-09-21 15:53:52,769 - WARNING - No data found for AOS and concepts ['Revenues', 'SalesRevenueNet']
# 2024-09-21 15:53:52,770 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:53:52,770 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:53:52,771 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:53:52,772 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:53:53,589 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:53:53,590 - ERROR - Failed to get data for AOS and concept PaymentsToAcquirePropertyPlantAndEquipment
# 2024-09-21 15:53:53,590 - WARNING - No data found for AOS and concepts ['PaymentsToAcquirePropertyPlantAndEquipment']
# 2024-09-21 15:53:53,591 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:53:53,591 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:54,402 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:54,403 - ERROR - Failed to get data for AOS and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:53:54,403 - WARNING - No data found for AOS and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:53:54,404 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:53:54,404 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:55,221 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:55,222 - ERROR - Failed to get data for AOS and concept ProceedsFromLongTermDebt
# 2024-09-21 15:53:55,223 - WARNING - No data found for AOS and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:53:55,223 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:53:56,047 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:53:56,048 - ERROR - Failed to get data for AOS and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:53:56,048 - WARNING - No data found for AOS and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:53:56,049 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:53:56,049 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000091142/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:53:56,050 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:56,055 - INFO - Saved financial data to fundamentals/aos-0000091142-financials.csv
# 2024-09-21 15:53:56,055 - INFO - Financial data for AOS saved to fundamentals/aos-0000091142-financials.csv
# 2024-09-21 15:53:56,556 - INFO - Processing ABT
# 2024-09-21 15:53:56,557 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:56,557 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:53:56,558 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:53:56,559 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:53:56,560 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:53:56,561 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/GrossProfit.json
# 2024-09-21 15:53:56,561 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/Revenues.json
# 2024-09-21 15:53:57,366 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/Revenues.json
# 2024-09-21 15:53:57,367 - ERROR - Failed to get data for ABT and concept Revenues
# 2024-09-21 15:53:57,367 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/SalesRevenueNet.json
# 2024-09-21 15:53:57,368 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:53:57,369 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:53:57,369 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:53:57,370 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:53:57,371 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:53:57,371 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:58,228 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:53:58,229 - ERROR - Failed to get data for ABT and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:53:58,230 - WARNING - No data found for ABT and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:53:58,230 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:53:58,230 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:59,078 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:53:59,079 - ERROR - Failed to get data for ABT and concept ProceedsFromLongTermDebt
# 2024-09-21 15:53:59,079 - WARNING - No data found for ABT and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:53:59,080 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:53:59,080 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:53:59,080 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000001800/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:53:59,081 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:59,088 - INFO - Saved financial data to fundamentals/abt-0000001800-financials.csv
# 2024-09-21 15:53:59,088 - INFO - Financial data for ABT saved to fundamentals/abt-0000001800-financials.csv
# 2024-09-21 15:53:59,589 - INFO - Processing ABBV
# 2024-09-21 15:53:59,589 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:53:59,590 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:53:59,591 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:53:59,592 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:53:59,592 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:53:59,593 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/GrossProfit.json
# 2024-09-21 15:53:59,593 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/Revenues.json
# 2024-09-21 15:53:59,594 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:53:59,594 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:53:59,595 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:53:59,595 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:53:59,596 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:53:59,596 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:00,389 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:00,390 - ERROR - Failed to get data for ABBV and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:54:00,390 - WARNING - No data found for ABBV and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:54:00,391 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:01,216 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/RepaymentsOfLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:01,216 - ERROR - Failed to get data for ABBV and concept RepaymentsOfLongTermDebt
# 2024-09-21 15:54:01,217 - WARNING - No data found for ABBV and concepts ['RepaymentsOfLongTermDebt']
# 2024-09-21 15:54:01,218 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:02,016 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:02,017 - ERROR - Failed to get data for ABBV and concept ProceedsFromLongTermDebt
# 2024-09-21 15:54:02,017 - WARNING - No data found for ABBV and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:54:02,017 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:02,018 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:02,820 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsOfDividendsCommonStock.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:02,821 - ERROR - Failed to get data for ABBV and concept PaymentsOfDividendsCommonStock
# 2024-09-21 15:54:02,821 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsOfDividends.json
# 2024-09-21 15:54:02,822 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001551152/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:54:02,823 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:02,826 - INFO - Saved financial data to fundamentals/abbv-0001551152-financials.csv
# 2024-09-21 15:54:02,827 - INFO - Financial data for ABBV saved to fundamentals/abbv-0001551152-financials.csv
# 2024-09-21 15:54:03,327 - INFO - Processing ACN
# 2024-09-21 15:54:03,328 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:03,329 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:54:03,330 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:54:03,331 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:54:03,332 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:03,332 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/GrossProfit.json
# 2024-09-21 15:54:04,200 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/GrossProfit.json
# 2024-09-21 15:54:04,201 - ERROR - Failed to get data for ACN and concept GrossProfit
# 2024-09-21 15:54:04,201 - WARNING - No data found for ACN and concepts ['GrossProfit']
# 2024-09-21 15:54:04,202 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/Revenues.json
# 2024-09-21 15:54:04,202 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:54:04,203 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:54:04,204 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:54:04,204 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:04,205 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:04,206 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:04,206 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:05,064 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/RepaymentsOfLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:05,065 - ERROR - Failed to get data for ACN and concept RepaymentsOfLongTermDebt
# 2024-09-21 15:54:05,065 - WARNING - No data found for ACN and concepts ['RepaymentsOfLongTermDebt']
# 2024-09-21 15:54:05,066 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:05,880 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:05,881 - ERROR - Failed to get data for ACN and concept ProceedsFromLongTermDebt
# 2024-09-21 15:54:05,881 - WARNING - No data found for ACN and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:54:05,882 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:06,724 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:06,725 - ERROR - Failed to get data for ACN and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:54:06,725 - WARNING - No data found for ACN and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:54:06,726 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:06,727 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001467373/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:54:06,727 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:06,732 - INFO - Saved financial data to fundamentals/acn-0001467373-financials.csv
# 2024-09-21 15:54:06,733 - INFO - Financial data for ACN saved to fundamentals/acn-0001467373-financials.csv
# 2024-09-21 15:54:07,234 - INFO - Processing ADBE
# 2024-09-21 15:54:07,235 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:07,236 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:54:07,237 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:54:07,238 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:54:07,239 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:07,239 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/GrossProfit.json
# 2024-09-21 15:54:07,240 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/Revenues.json
# 2024-09-21 15:54:07,241 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:54:07,241 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:54:07,242 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:54:07,243 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:07,243 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:07,244 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:08,106 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:08,107 - ERROR - Failed to get data for ADBE and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:54:08,107 - WARNING - No data found for ADBE and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:54:08,108 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:08,109 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:08,914 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:08,914 - ERROR - Failed to get data for ADBE and concept ProceedsFromLongTermDebt
# 2024-09-21 15:54:08,915 - WARNING - No data found for ADBE and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:54:08,916 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:08,916 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:09,773 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividendsCommonStock.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:09,774 - ERROR - Failed to get data for ADBE and concept PaymentsOfDividendsCommonStock
# 2024-09-21 15:54:09,775 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividends.json
# 2024-09-21 15:54:10,584 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividends.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsOfDividends.json
# 2024-09-21 15:54:10,585 - ERROR - Failed to get data for ADBE and concept PaymentsOfDividends
# 2024-09-21 15:54:10,585 - WARNING - No data found for ADBE and concepts ['PaymentsOfDividendsCommonStock', 'PaymentsOfDividends']
# 2024-09-21 15:54:10,586 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000796343/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:54:10,587 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:10,591 - INFO - Saved financial data to fundamentals/adbe-0000796343-financials.csv
# 2024-09-21 15:54:10,592 - INFO - Financial data for ADBE saved to fundamentals/adbe-0000796343-financials.csv
# 2024-09-21 15:54:11,093 - INFO - Processing AMD
# 2024-09-21 15:54:11,094 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:11,095 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:54:11,096 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:54:11,096 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:54:11,097 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:11,098 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/GrossProfit.json
# 2024-09-21 15:54:11,098 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/Revenues.json
# 2024-09-21 15:54:11,099 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:54:11,100 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:54:11,100 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:54:11,101 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:11,101 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:11,102 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:11,907 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:11,908 - ERROR - Failed to get data for AMD and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:54:11,908 - WARNING - No data found for AMD and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:54:11,909 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:11,909 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:12,791 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:12,792 - ERROR - Failed to get data for AMD and concept ProceedsFromLongTermDebt
# 2024-09-21 15:54:12,792 - WARNING - No data found for AMD and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:54:12,792 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:13,655 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:13,656 - ERROR - Failed to get data for AMD and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:54:13,656 - WARNING - No data found for AMD and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:54:13,657 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:14,451 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividendsCommonStock.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:14,452 - ERROR - Failed to get data for AMD and concept PaymentsOfDividendsCommonStock
# 2024-09-21 15:54:14,453 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividends.json
# 2024-09-21 15:54:15,254 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividends.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsOfDividends.json
# 2024-09-21 15:54:15,255 - ERROR - Failed to get data for AMD and concept PaymentsOfDividends
# 2024-09-21 15:54:15,255 - WARNING - No data found for AMD and concepts ['PaymentsOfDividendsCommonStock', 'PaymentsOfDividends']
# 2024-09-21 15:54:15,256 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000002488/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:54:15,257 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:15,261 - INFO - Saved financial data to fundamentals/amd-0000002488-financials.csv
# 2024-09-21 15:54:15,262 - INFO - Financial data for AMD saved to fundamentals/amd-0000002488-financials.csv
# 2024-09-21 15:54:15,763 - INFO - Processing AES
# 2024-09-21 15:54:15,764 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:15,765 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:54:15,765 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:54:15,766 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:54:15,767 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:16,581 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/OperatingIncomeLoss.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:16,582 - ERROR - Failed to get data for AES and concept OperatingIncomeLoss
# 2024-09-21 15:54:16,582 - WARNING - No data found for AES and concepts ['OperatingIncomeLoss']
# 2024-09-21 15:54:16,583 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/GrossProfit.json
# 2024-09-21 15:54:16,584 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/Revenues.json
# 2024-09-21 15:54:16,585 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:54:16,585 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:54:16,586 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:54:16,587 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:16,587 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:17,406 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:17,407 - ERROR - Failed to get data for AES and concept PaymentsToAcquireBusinessesNetOfCashAcquired
# 2024-09-21 15:54:17,407 - WARNING - No data found for AES and concepts ['PaymentsToAcquireBusinessesNetOfCashAcquired']
# 2024-09-21 15:54:17,408 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:18,300 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:18,301 - ERROR - Failed to get data for AES and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:54:18,302 - WARNING - No data found for AES and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:54:18,302 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:19,135 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/RepaymentsOfLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:19,136 - ERROR - Failed to get data for AES and concept RepaymentsOfLongTermDebt
# 2024-09-21 15:54:19,136 - WARNING - No data found for AES and concepts ['RepaymentsOfLongTermDebt']
# 2024-09-21 15:54:19,137 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:19,962 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:19,963 - ERROR - Failed to get data for AES and concept ProceedsFromLongTermDebt
# 2024-09-21 15:54:19,968 - WARNING - No data found for AES and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:54:19,968 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:20,804 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:54:20,805 - ERROR - Failed to get data for AES and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:54:20,806 - WARNING - No data found for AES and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:54:20,806 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:54:20,807 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000874761/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:54:20,808 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:20,813 - INFO - Saved financial data to fundamentals/aes-0000874761-financials.csv
# 2024-09-21 15:54:20,813 - INFO - Financial data for AES saved to fundamentals/aes-0000874761-financials.csv
# 2024-09-21 15:54:21,314 - INFO - Processing AFL
# 2024-09-21 15:54:21,315 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:54:21,316 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:54:21,317 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:54:21,317 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:54:21,318 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:54:21,319 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/GrossProfit.json
# 2024-09-21 15:54:22,138 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/GrossProfit.json
# 2024-09-21 15:54:22,139 - ERROR - Failed to get data for AFL and concept GrossProfit
# 2024-09-21 15:54:22,139 - WARNING - No data found for AFL and concepts ['GrossProfit']
# 2024-09-21 15:54:22,140 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/Revenues.json
# 2024-09-21 15:54:22,141 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:54:22,142 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:54:22,142 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:54:22,143 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:22,958 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:54:22,959 - ERROR - Failed to get data for AFL and concept PaymentsToAcquirePropertyPlantAndEquipment
# 2024-09-21 15:54:22,967 - WARNING - No data found for AFL and concepts ['PaymentsToAcquirePropertyPlantAndEquipment']
# 2024-09-21 15:54:22,968 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:54:22,969 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:23,788 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:54:23,789 - ERROR - Failed to get data for AFL and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:54:23,789 - WARNING - No data found for AFL and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:54:23,790 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:54:23,790 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:54:24,632 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000004977/us-gaap/ProceedsFromLongTermDebt.json
# ...
# 2024-09-21 15:58:43,170 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:58:43,171 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:58:43,172 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/GrossProfit.json
# 2024-09-21 15:58:43,858 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/GrossProfit.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/GrossProfit.json
# 2024-09-21 15:58:43,859 - ERROR - Failed to get data for AME and concept GrossProfit
# 2024-09-21 15:58:43,859 - WARNING - No data found for AME and concepts ['GrossProfit']
# 2024-09-21 15:58:43,860 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/Revenues.json
# 2024-09-21 15:58:44,450 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/Revenues.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/Revenues.json
# 2024-09-21 15:58:44,451 - ERROR - Failed to get data for AME and concept Revenues
# 2024-09-21 15:58:44,452 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/SalesRevenueNet.json
# 2024-09-21 15:58:45,295 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:58:46,064 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:58:46,901 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:58:47,692 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:58:48,522 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:58:49,325 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:58:49,863 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:58:49,864 - ERROR - Failed to get data for AME and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:58:49,864 - WARNING - No data found for AME and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:58:49,865 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:58:50,638 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:58:51,199 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:58:51,200 - ERROR - Failed to get data for AME and concept ProceedsFromLongTermDebt
# 2024-09-21 15:58:51,201 - WARNING - No data found for AME and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:58:51,201 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:58:51,737 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsOfDebtIssuanceCosts.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:58:51,738 - ERROR - Failed to get data for AME and concept PaymentsOfDebtIssuanceCosts
# 2024-09-21 15:58:51,739 - WARNING - No data found for AME and concepts ['PaymentsOfDebtIssuanceCosts']
# 2024-09-21 15:58:51,739 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:58:52,562 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0001037868/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:58:53,397 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:58:53,403 - INFO - Saved financial data to fundamentals/ame-0001037868-financials.csv
# 2024-09-21 15:58:53,403 - INFO - Financial data for AME saved to fundamentals/ame-0001037868-financials.csv
# 2024-09-21 15:58:53,904 - INFO - Processing AMGN
# 2024-09-21 15:58:53,905 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:58:53,906 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:58:53,907 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:58:53,908 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:58:53,910 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:58:53,911 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/GrossProfit.json
# 2024-09-21 15:58:53,911 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/Revenues.json
# 2024-09-21 15:58:53,912 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:58:54,772 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:58:55,539 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:58:56,297 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:58:57,102 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:58:58,055 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:58:58,920 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:58:59,722 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:59:00,256 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:59:00,257 - ERROR - Failed to get data for AMGN and concept ProceedsFromLongTermDebt
# 2024-09-21 15:59:00,257 - WARNING - No data found for AMGN and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:59:00,258 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:59:01,107 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:59:01,897 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000318154/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:59:02,748 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:59:02,754 - INFO - Saved financial data to fundamentals/amgn-0000318154-financials.csv
# 2024-09-21 15:59:02,755 - INFO - Financial data for AMGN saved to fundamentals/amgn-0000318154-financials.csv
# 2024-09-21 15:59:03,256 - INFO - Processing APH
# 2024-09-21 15:59:03,257 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:59:03,258 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:59:03,259 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:59:03,260 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:59:03,260 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:59:03,261 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/GrossProfit.json
# 2024-09-21 15:59:03,262 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/Revenues.json
# 2024-09-21 15:59:03,262 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:59:04,444 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:59:05,532 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:59:06,565 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:59:07,642 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:59:08,744 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:59:09,538 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:59:09,539 - ERROR - Failed to get data for APH and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:59:09,539 - WARNING - No data found for APH and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:59:09,540 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:59:10,657 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:59:11,485 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/ProceedsFromLongTermDebt.json
# 2024-09-21 15:59:11,486 - ERROR - Failed to get data for APH and concept ProceedsFromLongTermDebt
# 2024-09-21 15:59:11,487 - WARNING - No data found for APH and concepts ['ProceedsFromLongTermDebt']
# 2024-09-21 15:59:11,487 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/PaymentsOfDebtIssuanceCosts.json
# 2024-09-21 15:59:12,642 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/PaymentsOfDividendsCommonStock.json
# 2024-09-21 15:59:13,725 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000820313/us-gaap/PaymentsForRepurchaseOfCommonStock.json
# 2024-09-21 15:59:14,863 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:59:14,868 - INFO - Saved financial data to fundamentals/aph-0000820313-financials.csv
# 2024-09-21 15:59:14,869 - INFO - Financial data for APH saved to fundamentals/aph-0000820313-financials.csv
# 2024-09-21 15:59:15,370 - INFO - Processing ADI
# 2024-09-21 15:59:15,370 - INFO - Loading cached file for https://www.sec.gov/include/ticker.txt
# 2024-09-21 15:59:15,372 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/EarningsPerShareBasic.json
# 2024-09-21 15:59:15,373 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/EarningsPerShareDiluted.json
# 2024-09-21 15:59:15,373 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/NetIncomeLoss.json
# 2024-09-21 15:59:15,374 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/OperatingIncomeLoss.json
# 2024-09-21 15:59:15,375 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/GrossProfit.json
# 2024-09-21 15:59:15,376 - INFO - Loading cached file for https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/Revenues.json
# 2024-09-21 15:59:15,377 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/NetCashProvidedByUsedInOperatingActivities.json
# 2024-09-21 15:59:16,473 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/NetCashProvidedByUsedInInvestingActivities.json
# 2024-09-21 15:59:17,554 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/NetCashProvidedByUsedInFinancingActivities.json
# 2024-09-21 15:59:18,668 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/PaymentsToAcquirePropertyPlantAndEquipment.json
# 2024-09-21 15:59:19,689 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/PaymentsToAcquireBusinessesNetOfCashAcquired.json
# 2024-09-21 15:59:20,710 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:59:21,522 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/ProceedsFromDivestitureOfBusinessesNetOfCashDivested.json
# 2024-09-21 15:59:21,523 - ERROR - Failed to get data for ADI and concept ProceedsFromDivestitureOfBusinessesNetOfCashDivested
# 2024-09-21 15:59:21,523 - WARNING - No data found for ADI and concepts ['ProceedsFromDivestitureOfBusinessesNetOfCashDivested']
# 2024-09-21 15:59:21,524 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:59:22,380 - ERROR - Error downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/RepaymentsOfLongTermDebt.json: 404 Client Error: Not Found for url: https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/RepaymentsOfLongTermDebt.json
# 2024-09-21 15:59:22,381 - ERROR - Failed to get data for ADI and concept RepaymentsOfLongTermDebt
# 2024-09-21 15:59:22,382 - WARNING - No data found for ADI and concepts ['RepaymentsOfLongTermDebt']
# 2024-09-21 15:59:22,382 - INFO - Downloading https://data.sec.gov/api/xbrl/companyconcept/CIK0000006281/us-gaap/ProceedsFromLongTermDebt.json
